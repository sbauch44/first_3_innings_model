# %%
import sys
import pathlib

sys.path.append(str(pathlib.Path(pathlib.Path.cwd()).parent))

# from baseball_simulator.data_fetcher import fetch_fangraphs_projections

import polars as pl

pl.Config.set_tbl_cols(200)
# Out:
# polars.config.Config

# %%
pit_proj_df = fetch_fangraphs_projections('pit')
bat_proj_df = fetch_fangraphs_projections('bat')

# %%
print(pit_proj_df.head(2))
# Out:
# shape: (2, 47)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ Tea ┆ Sho ┆ W   ┆ L   ┆ GS  ┆ G   ┆ SV  ┆ HLD ┆ BS  ┆ IP  ┆ TBF ┆ H   ┆ R   ┆ ER  ┆ HR  ┆ SO  ┆ BB  ┆ IBB ┆ HBP ┆ ERA ┆ WHI ┆ K/9 ┆ BB/ ┆ K/B ┆ HR/ ┆ K%  ┆ BB% ┆ K-B ┆ GB% ┆ AVG ┆ BAB ┆ LOB ┆ FIP ┆ FPT ┆ FPT ┆ SPT ┆ SPT ┆ WAR ┆ RA9 ┆ QS  ┆ ADP ┆ tea ┆ Lea ┆ Pla ┆ xML ┆ pla ┆ pla │
# │ m   ┆ rtN ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ P   ┆ --- ┆ 9   ┆ B   ┆ 9   ┆ --- ┆ --- ┆ B%  ┆ --- ┆ --- ┆ IP  ┆ %   ┆ --- ┆ S   ┆ S_I ┆ S   ┆ S_I ┆ --- ┆ -WA ┆ --- ┆ --- ┆ mid ┆ gue ┆ yer ┆ BAM ┆ yer ┆ yer │
# ...

# %%
bat_proj_df.head()
# Out:
# shape: (5, 57)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ Tea ┆ Sho ┆ G   ┆ AB  ┆ PA  ┆ H   ┆ 1B  ┆ 2B  ┆ 3B  ┆ HR  ┆ R   ┆ RBI ┆ BB  ┆ IBB ┆ SO  ┆ HBP ┆ SF  ┆ SH  ┆ GDP ┆ SB  ┆ CS  ┆ AVG ┆ OBP ┆ SLG ┆ OPS ┆ wOB ┆ BB% ┆ K%  ┆ BB/ ┆ ISO ┆ Spd ┆ BAB ┆ UBR ┆ GDP ┆ wRC ┆ wRA ┆ UZR ┆ wBs ┆ Bas ┆ WAR ┆ Off ┆ Def ┆ wRC ┆ FPT ┆ FPT ┆ SPT ┆ SPT ┆ ADP ┆ Pos ┆ min ┆ UPU ┆ tea ┆ Lea ┆ Pla ┆ xML ┆ pla ┆ pla │
# ...

# %%
import statsapi

def fetch_player_info():
    json_resp= statsapi.get("people", {"personIds": '660271,605141'})
    return json_resp

# %%
# json_resp
# Out:
# {'copyright': 'Copyright 2025 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'people': [{'id': 660271,
#    'fullName': 'Shohei Ohtani',
#    'link': '/api/v1/people/660271',
#    'firstName': 'Shohei',
#    'lastName': 'Ohtani',
#    'primaryNumber': '17',
#    'birthDate': '1994-07-05',
#    'currentAge': 30,
#    'birthCity': 'Oshu',
#    'birthCountry': 'Japan',
#    'height': '6\' 3"',
#    'weight': 210,
#    'active': True,
#    'primaryPosition': {'code': 'Y',
#     'name': 'Two-Way Player',
#     'type': 'Two-Way Player',
#     'abbreviation': 'TWP'},
#    'useName': 'Shohei',
#    'useLastName': 'Ohtani',
#    'boxscoreName': 'Ohtani',
#    'nickName': 'Showtime',
#    'gender': 'M',
#    'isPlayer': True,
#    'isVerified': False,
#    'pronunciation': 'show-HEY oh-TAWN-ee',
#    'mlbDebutDate': '2018-03-29',
#    'batSide': {'code': 'L', 'description': 'Left'},
# ...

# %%
def_df = pl.read_parquet('../clean_data/clean_defensive_stats.parquet')
def_df.head(10)
# Out:
# shape: (10, 7)
# ┌───────────┬──────┬───────────────┬───────────────┬───────────────┬───────────────┬───────────────┐
# │ player_id ┆ year ┆ outs_above_av ┆ total_innings ┆ cumulative_oa ┆ cumulative_in ┆ outs_above_av │
# │ ---       ┆ ---  ┆ erage         ┆ _played       ┆ a_prior       ┆ nings_prior   ┆ erage_per_inn │
# │ i64       ┆ i64  ┆ ---           ┆ ---           ┆ ---           ┆ ---           ┆ ing           │
# │           ┆      ┆ i64           ┆ u32           ┆ i64           ┆ u32           ┆ ---           │
# │           ┆      ┆               ┆               ┆               ┆               ┆ f64           │
# ╞═══════════╪══════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 444482    ┆ 2021 ┆ 5             ┆ 1078          ┆ 0             ┆ 0             ┆ 0.0           │
# │ 444482    ┆ 2022 ┆ 5             ┆ 928           ┆ 5             ┆ 1078          ┆ 0.004638      │
# ...

# %%
df.head()
# Out:
# shape: (5, 59)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ gam ┆ at_ ┆ pit ┆ bat ┆ pit ┆ eve ┆ sta ┆ p_t ┆ inn ┆ hom ┆ awa ┆ gam ┆ gam ┆ bb_ ┆ bal ┆ str ┆ out ┆ inn ┆ gam ┆ fie ┆ fie ┆ fie ┆ fie ┆ fie ┆ fie ┆ fie ┆ fie ┆ pa_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ is_ ┆ bat ┆ bat ┆ bat ┆ bat ┆ bat ┆ bat ┆ bat ┆ bat ┆ bat ┆ pit ┆ pit ┆ pit ┆ pit ┆ pit ┆ pit ┆ pit ┆ pit ┆ pit ┆ is_ ┆ is_ │
# ...

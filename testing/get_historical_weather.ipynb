# %%
# !pip install MLB-StatsAPI

# %%
import requests
import polars as pl
import datetime
import statsapi

# %%
box_score = statsapi.boxscore_data(778258)
box_score
# Out:
# {'gameId': '2025/04/19/seamlb-tormlb-1',
#  'teamInfo': {'away': {'id': 136,
#    'abbreviation': 'SEA',
#    'teamName': 'Mariners',
#    'shortName': 'Seattle'},
#   'home': {'id': 141,
#    'abbreviation': 'TOR',
#    'teamName': 'Blue Jays',
#    'shortName': 'Toronto'}},
#  'playerInfo': {'ID666182': {'id': 666182,
#    'fullName': 'Bo Bichette',
#    'boxscoreName': 'Bichette'},
#   'ID641487': {'id': 641487,
#    'fullName': 'J.P. Crawford',
#    'boxscoreName': 'Crawford, J'},
#   'ID687922': {'id': 687922,
#    'fullName': 'Easton Lucas',
#    'boxscoreName': 'Lucas'},
#   'ID642133': {'id': 642133,
#    'fullName': 'Rowdy Tellez',
#    'boxscoreName': 'Tellez'},
#   'ID676391': {'id': 676391,
#    'fullName': 'Ernie Clement',
#    'boxscoreName': 'Clement'},
#   'ID665926': {'id': 665926,
#    'fullName': 'Andrés Giménez',
#    'boxscoreName': 'Gimenez'},
#   'ID656546': {'id': 656546,
#    'fullName': 'Jeff Hoffman',
#    'boxscoreName': 'Hoffman'},
# ...

# %%
import requests
import polars as pl
import datetime
import statsapi

# %%
box_score = statsapi.boxscore_data(777547)
box_score
# Out:
# {'gameId': '2025/06/11/sfnmlb-colmlb-1',
#  'teamInfo': {'away': {'id': 137,
#    'abbreviation': 'SF',
#    'teamName': 'Giants',
#    'shortName': 'San Francisco'},
#   'home': {'id': 115,
#    'abbreviation': 'COL',
#    'teamName': 'Rockies',
#    'shortName': 'Colorado'}},
#  'playerInfo': {'ID666464': {'id': 666464,
#    'fullName': 'Jerar Encarnacion',
#    'boxscoreName': 'Encarnacion'},
#   'ID669374': {'id': 669374,
#    'fullName': 'Keston Hiura',
#    'boxscoreName': 'Hiura'},
#   'ID671218': {'id': 671218,
#    'fullName': 'Heliot Ramos',
#    'boxscoreName': 'Ramos'},
#   'ID680767': {'id': 680767,
#    'fullName': 'Victor Vodnik',
#    'boxscoreName': 'Vodnik'},
#   'ID642731': {'id': 642731,
#    'fullName': 'Thairo Estrada',
#    'boxscoreName': 'Estrada'},
#   'ID668800': {'id': 668800,
#    'fullName': 'Andrew Knizner',
#    'boxscoreName': 'Knizner'},
#   'ID666149': {'id': 666149,
#    'fullName': 'Tyler Fitzgerald',
#    'boxscoreName': 'Fitzgerald'},
# ...

# %%
df = pl.read_parquet("../raw_data/weather_data.parquet")
df.head()
# Out:
# shape: (5, 18)
# ┌─────────┬───────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ game_id ┆ away_team ┆ away_team_ ┆ home_team ┆ … ┆ roof_clos ┆ wind_spee ┆ wind_dire ┆ wind_affe │
# │ ---     ┆ ---       ┆ id         ┆ ---       ┆   ┆ ed        ┆ d_mph     ┆ ction     ┆ cts_play  │
# │ i64     ┆ str       ┆ ---        ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆           ┆ i64        ┆           ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞═════════╪═══════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 719327  ┆ Unknown   ┆ 111        ┆ Unknown   ┆ … ┆ null      ┆ 3         ┆ Out To LF ┆ true      │
# │ 719330  ┆ Unknown   ┆ 134        ┆ Unknown   ┆ … ┆ null      ┆ 6         ┆ In From   ┆ true      │
# │         ┆           ┆            ┆           ┆   ┆           ┆           ┆ CF        ┆           │
# ...
